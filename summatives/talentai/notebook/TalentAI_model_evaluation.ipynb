# %%
import pandas as pd
import pickle
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# %%
# Load data
data = pd.read_csv('/home/kalu/alu-machine_learning/summatives/talentai/data/train/training_data.csv')

# Display the first few rows of the dataset
data.head()
# Out:
#    artist_id    artist_name  age     genre       country experience_level  \
# 0          1       John Doe   30  Afrobeat       Nigeria     Professional
# 1          2     Mary Smith   25   Hip Hop  South Africa     Intermediate
# 2          3     Ali Hassan   28    Reggae         Kenya         Beginner
# 3          4  Chinwe Okafor   32      Jazz       Nigeria     Professional
# 4          5   Mpho Dlamini   22      Soul  South Africa         Beginner
#
#    track_id       track_title duration release_date  streams  likes  comments  \
# 0         1     African Vibes     3:45   2023-05-10     5000    300        25
# 1         2       Urban Beats     4:20   2023-06-15     3500    200        15
# 2         3    Reggae Rhythms     5:05   2023-07-01     4200    250        20
# 3         4  Jazz in the City     6:30   2023-08-12     2500    150        10
# 4         5   Soulful Harmony     4:15   2023-09-05     3000    180        12
#
# ...

# %%
# Define features and target
# Predicting total revenue based on other features
X = data[['age', 'genre', 'country', 'duration', 'streams', 'likes', 'comments']]
y = data['total_revenue']  # Target variable

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Save the trained model as a .pkl file
with open('/home/kalu/alu-machine_learning/summatives/talentai/models/talentai_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
# Optional: Print out the shapes of the splits to verify
print(f"Training set: {X_train.shape}, {y_train.shape}")
print(f"Testing set: {X_test.shape}, {y_test.shape}")
# Out:
# Training set: (3, 7), (3,)
# Testing set: (2, 7), (2,)
